# %%
import ssl
import certifi
import pandas as pd
from pathlib import Path 
import os
import time
from datetime import datetime
# Out:
# The kernel failed to start as a dll could not be loaded.
#
# Click <a href='https://aka.ms/kernelFailuresDllLoad'>here</a> for more info.

# %%
# Assign a function that RETURNS the context, rather than the context itself
# ssl._create_default_https_context = ssl._create_unverified_context
# TODO: This needs to be validated: failed to run on a couple of occasions
ssl._create_default_https_context = lambda: ssl.create_default_context(cafile=certifi.where())

# %% [markdown]
# **Formalizing Download Approach**

# %%
# TABLE DOCUMENTATION
# For reference, check documentation: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/documentation/ACS20241YR_Table_Shells.txt
ACS_TABLE_DOC = {
    "B01003": {
        "title": "Total Population",
        "topic": "Population",
        "uids": ["B01003_001"],
        "years": [2022, 2023, 2024],
    },

    "B07003": {
        "title": "Geographic Mobility (1 Year)",
        "topic": "Migration",
        "uids": [
            "B07003_001", # Total population
            "B07003_004", # Same house 1 year ago
            "B07003_007", # Moved within the same county
            "B07003_010", # Moved from different county within the same state
            "B07003_013", # Moved from different state
            "B07003_016", # Moved from abroad
        ],
        "years": [2022, 2023, 2024],
    },

    "B11001": {
        "title": "Household Type",
        "topic": "Households",
        "uids": [
            "B11001_001", # Total households - we start with this
            "B11001_002", # Family households
            "B11001_003", # Married-couple households
            "B11001_004", # Other family households
            "B11001_007", # Nonfamily
            "B11001_008", # Householder living alone
            "B11001_009", # Not living alone
        ],
        "years": [2022, 2023, 2024],
    },

     "B19001": {
        "title": "Household Income Distribution",
        "topic": "Income",
        "uids": [f"B19001_{i:03d}" for i in range(1, 18)], # Total Households; Distribution across Income Brackets, last bracket is $200,000 or more
        "years": [2022, 2023, 2024],
    },

    "B19013": {
        "title": "Median Household Income", 
        "topic": "Income",
        "uids": ["B19013_001"], # Median household income
        "years": [2022, 2023, 2024],
    },

    "B25001": {
        "title": "Housing Units",
        "topic": "Housing",
        "uids": ["B25001_001"], # Total housing units
        "years": [2022, 2023, 2024],
    },

    "B25002": {
        "title": "Occupancy Status",
        "topic": "Housing",
        "uids": [
            "B25002_001", # Total Housing Units
            "B25002_002", # Occupied
            "B25002_003" # Vacant
            ], 
        "years": [2022, 2023, 2024],
    },

    "B25003": {
        "title": "Tenure (Owner / Renter)",
        "topic": "Housing",
        "uids": [
            "B25003_001", # Total Occupied Housing Units
            "B25003_002", # Total Owner-occupied Housing Units
            "B25003_003" # Total Renter-occupied Housing Units
            ],
        "years": [2022, 2023, 2024],
    },

     "B25024": {
        "title": "Units in Structure",
        "topic": "Housing Stock",
        "uids": [f"B25024_{i:03d}" for i in range(1, 12)], # Total Units in Structure, Splits by number of units
        "years": [2022, 2023, 2024],
    },

    "B25077": {
        "title": "Median Home Value",
        "topic": "Home Value",
        "uids": ["B25077_001"], # Median Home Value in USD
        "years": [2022, 2023, 2024],
    },

    "C17002": {
        "title": "Ratio of Income to Poverty Level",
        "uids": [f"C17002_{i:03d}" for i in range(1, 9)], # Ratio of Income to Poverty Level; Splits by income-to-poverty ratio
        "years": [2022, 2023, 2024],
    },
}

# %%
# Helper function to find root folder
# Downloaded ACS data should be stored in root folder/ data / raw / ACS
def find_project_root(start:Path | None=None)-> Path:
    '''
    Objective is to find a marker such as .toml, .git or a directory that points to root
    '''
    start = start or Path.cwd()
    for p in [start, *start.parents]:
        if (p / ".git").exists() or (p / "pyproject.toml").exists() or (p / "data").exists():
            return p
    raise FileNotFoundError("Project root not found")

# %%
# Helper function to define output directory
def ensure_outdir(outdir:Path) -> None:
    '''
    Ensure that the output directory exists. If it does not exist, create it.
    Output data directory should ideally be root / data / raw / ACS; i.e.
    '''
    os.makedirs(outdir, exist_ok=True)

# %%
# Helper function to build URL for 5 year ACS
def build_file_url(year:int, dataset:int,table_id:str) -> str:
    '''
    Build the download URL for ACS table data.
    
    Args:
        year: The year for the data (defaults to YEAR constant)
        dataset: ACS dataset identifier (e.g., 1 for 1-year, 5 for 5-year)
        table_id: The ACS table identifier (e.g., 'B01001')
    Returns:
        Complete URL string for downloading the table
    '''
    # ACS DOWNLOAD URL
    base_url = f"https://www2.census.gov/programs-surveys/acs/summary_file/{year}/table-based-SF/data/{dataset}YRData/acsdt{dataset}y{year}"
    filename = f"-{table_id.lower()}.dat"
    return base_url + filename

# %%
# Helper to convert columns from ACS data dictionary to actual columns in dat files
def get_acs_downloadable_columns(table_id:str, uids:list[str]) -> list[str]:
    '''
    '''
    cols = []
    for uid in uids:
        num = uid.split("_")[1] # "001"
        cols.append(f"{table_id}_E{num}")
        cols.append(f"{table_id}_M{num}")
    return cols

# %%
# Function to download and filter ACS data
def download_and_filter(file_url:str,
                        sumlevel:str,
                        state:str,
                        usecols:list[str]) -> pd.DataFrame:
    '''
    Downloads ACS table(s) and filters to:
        -sumlevel: geographic level; for example "140" for tract and "150" for block group
        -state: state code; for example "06" for California
    '''
    # Read data from the URL provided
    df = pd.read_csv(file_url, sep = "|", dtype=str, usecols=usecols)

    # Filter to summary level
    df = df[df["GEO_ID"].str.startswith(sumlevel)]

    # # Filter to state if testing
    if state != "all":
        # # GEO_ID looks like: {sumlevel}0000US{state}-{county}-{tract}
        prefix = f"{sumlevel}0000US{state.zfill(2)}"
        df = df[df["GEO_ID"].str.startswith(prefix)]
        
    return df

# %%
# Helper function to validate desired columns exist in dataframe header
def validate_columns_exist(df: pd.DataFrame, required_cols: list[str]) -> None:
    '''
    Once the dataframe is downloaded, check all defined columns exist in the downloaded file
    If columns don't exist, raise an exception
    '''
    # Obtain columns from dataframe header
    available = df.head(0).columns.tolist()

    # Define missing
    missing = [c for c in required_cols if c not in available]
    if missing:
        # Show sample for debugging
        sample_available = sorted(available)[:5]
        raise ValueError(
            f"Missing {len(missing)} columns: {missing}.\n"
            f"Sample available columns: {sample_available}"
            )

# %%
# Function to obtain one table from ACS data
# Right now, we obtain for one state
# TODO: Extend this function to handle multiple tables and multiple states
def get_acs_for_sumlevel(
        year:int,
        dataset:int,
        table_id:str,
        state:str,
        sumlevel: str,
        outdir:Path,
        ) -> pd.DataFrame:
    '''
    Orchestrates: pick cols -> download -> filter -> save output
    Parameters:
        - table_id: ACS table ID to download
        - state: This can either be "all" or a two-digit state code (e.g., "06" for California)
        - sumlevel: Geographic summary level; for example "140" for tract and "150" for block group
        - outdir: Directory to save the downloaded data
        - year: Year of the ACS data
    Returns output path
    '''
    start_time = time.time()
    
    # Ensure output directory exists
    ensure_outdir(outdir)

    # Ensure desired table has been added to docs
    if table_id not in ACS_TABLE_DOC:
        print(f"Note:{table_id} not in ACS TABLE DOCS. Add it please for better documentation!")
        meta = None
    # Check print statements: not all of them are necessary
    else:
        meta = ACS_TABLE_DOC[table_id]
        print(f"\n Table: {table_id} - {meta['title']}")
        #print(f"Why: {meta["why_we_care"]}")
        print(f"Columns: {meta['uids']}")
        #print(f"Notes: {meta['notes']}")

    # Define the file url
    file_url = build_file_url(year=year, dataset=1, table_id=table_id)
    print(f"\n Fetching from: {file_url}")

    # Define the cols that need to be extracted
    keep_cols = ["GEO_ID"] + get_acs_downloadable_columns(table_id, meta['uids'])
    print(f"Keeping {len(keep_cols)} columns including GEO_ID + {table_id} E/M cols")

    # Extract the relevant data
    # Normalize state just in case
    state = state.lower()
    df = download_and_filter(file_url, sumlevel=sumlevel, state=state, usecols=keep_cols)

    # Validate that all columns exist in the dataframe
    # Raises an exception even if one column is missing
    validate_columns_exist(df, keep_cols)

    # Save the extracted data
    geo_name = "subdivision" if sumlevel == "060" else"place" if sumlevel == "160" else "tract" if sumlevel == "140" else "block_group" if sumlevel == "150" else "unknown_geo"
    outpath = os.path.join(outdir, f"{table_id}_{geo_name}_state_{state}_{year}.csv")
    df.to_csv(outpath, index=False)
    print(f"Saved: {outpath}")
    
    # Ops measures
    print(f'File size {os.path.getsize(outpath) / (1024 * 1024):.2f} MB')
    end_time = time.time()
    print(f"Time taken to download and save data: {end_time - start_time:.2f} seconds")
    return df

# %%
# Test run for one table, one state
# ACS DOWNLOAD URL
DATASET = 1
YEAR = 2023
STATE = "All"
TABLE = "B01003"
# Summary level dictionary for reference
SUM_LEVEL_DICT = {
    '010': 'nation',
    '040': 'state', 
    '050': 'county',
    '060': 'county_subdivision', 
    '140': 'census_tract',
    '150': 'block_group',
    '160': 'place',
    '310': 'cbsa',
    '860': 'zcta', 
    '950': 'el_sch_dist', 
    '960': 'sec_sch_dist',
    '970': 'uni_sch_dist'
}

# Change this based on sumlevel
OUTDIR = find_project_root() / f"data/raw/ACS/1yr/sumlevel_{SUM_LEVEL_DICT['160']}"

# Get data for census tracts
df_tracts = get_acs_for_sumlevel(
    dataset=DATASET,
    year=YEAR,
    table_id = TABLE,
    state=STATE,
    sumlevel='160',
    outdir=OUTDIR
)
# Out:
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B01003_place_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.65 seconds

# %%
# Function to run a batch download
def batch_download_acs(
        dataset:int,
        years:list[int],
        sumlevels: list[str],
        states: list[str],
        tables: list[str],
        outdir:dict[str, Path],
        ) -> None:
    '''
    Orchestrates downloads across:
        - years: multiple ACS years
        - tables (default: all keys in ACS_TABLE_DOC)
        - sumlevels (default: ["140", "150"])
        - states (default: ['all'])
    Writes:
        - CSV files for each table, sumlevel, and state combination in the specified output directory
    '''
    # Adding some basic checks first
    if years is None:
        years = [2022,2023,2024]
    if sumlevels is None:
        sumlevels = ["060", "160"]
    if states is None:
        states = ['all']
    if tables is None:
        tables = list(ACS_TABLE_DOC.keys())
    
    # TODO: In case we want to capture timestamps in a metadata file later
    # start_time = datetime.now()

    total_jobs = len(years) * len(tables) * len(sumlevels) * len(states)
    job_num = 0
    for year in years:
        for table_id in tables:
            for sumlevel in sumlevels:
                if sumlevel == "060":
                    final_path = outdir["060"]
                elif sumlevel == "160":
                    final_path = outdir["160"]
                for state in states:
                    job_num += 1
                    print(f"Starting job {job_num}/{total_jobs}: Year {year}, Table {table_id}, Sumlevel {sumlevel}, State {state}")

                    # Call the function to download the ACS data for the given table, sumlevel, and state
                    try:
                        get_acs_for_sumlevel(
                        dataset=dataset,
                        year = year,
                        table_id=table_id,
                        state=state,
                        sumlevel=sumlevel,
                        outdir=final_path)
                    except Exception as e:
                        print(f"Error in job {job_num}/{total_jobs}: Table {table_id}, Sumlevel {sumlevel}, State {state}")

# %%
# Run the orchestrator to download all tables for both sumlevels and all states
# ACS DOWNLOAD URL
DATASET = 1
YEARS = [2022, 2023, 2024]
TABLE = "B01003"

# Change this based on sumlevel
OUTDIR_PLACE = find_project_root() / f"data/raw/ACS/1yr/sumlevel_{SUM_LEVEL_DICT['160']}"
OUTDIR_SD = find_project_root() / f"data/raw/ACS/1yr/sumlevel_{SUM_LEVEL_DICT['060']}"

# Function call 
batch_download_acs(
    dataset=DATASET,
    years = YEARS,
    sumlevels=["060", "160"],
    states=['all'],
    tables=list(ACS_TABLE_DOC.keys()), # For testing, use TABLE = ["B01003"], to fetch all use list(ACS_TABLE_DOC.keys())
    outdir={"060": OUTDIR_SD, "160": OUTDIR_PLACE}
)
# Out:
# Starting job 1/66: Year 2022, Table B01003, Sumlevel 060, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B01003_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.98 seconds
# Starting job 2/66: Year 2022, Table B01003, Sumlevel 160, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B01003_place_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 0.38 seconds
# Starting job 3/66: Year 2022, Table B07003, Sumlevel 060, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B07003_subdivision_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 1.47 seconds
# Starting job 4/66: Year 2022, Table B07003, Sumlevel 160, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B07003_place_state_all_2022.csv
# File size 0.05 MB
# Time taken to download and save data: 0.38 seconds
# Starting job 5/66: Year 2022, Table B11001, Sumlevel 060, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B11001_subdivision_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 0.88 seconds
# Starting job 6/66: Year 2022, Table B11001, Sumlevel 160, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B11001_place_state_all_2022.csv
# File size 0.06 MB
# Time taken to download and save data: 0.41 seconds
# Starting job 7/66: Year 2022, Table B19001, Sumlevel 060, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19001_subdivision_state_all_2022.csv
# File size 0.04 MB
# Time taken to download and save data: 0.88 seconds
# Starting job 8/66: Year 2022, Table B19001, Sumlevel 160, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19001_place_state_all_2022.csv
# File size 0.11 MB
# Time taken to download and save data: 0.42 seconds
# Starting job 9/66: Year 2022, Table B19013, Sumlevel 060, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19013_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.83 seconds
# Starting job 10/66: Year 2022, Table B19013, Sumlevel 160, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19013_place_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 0.37 seconds
# Starting job 11/66: Year 2022, Table B25001, Sumlevel 060, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25001_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.68 seconds
# Starting job 12/66: Year 2022, Table B25001, Sumlevel 160, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25001_place_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 0.34 seconds
# Starting job 13/66: Year 2022, Table B25002, Sumlevel 060, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25002_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.84 seconds
# Starting job 14/66: Year 2022, Table B25002, Sumlevel 160, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25002_place_state_all_2022.csv
# File size 0.03 MB
# Time taken to download and save data: 0.36 seconds
# Starting job 15/66: Year 2022, Table B25003, Sumlevel 060, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25003_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.83 seconds
# Starting job 16/66: Year 2022, Table B25003, Sumlevel 160, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25003_place_state_all_2022.csv
# File size 0.03 MB
# Time taken to download and save data: 0.37 seconds
# Starting job 17/66: Year 2022, Table B25024, Sumlevel 060, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25024_subdivision_state_all_2022.csv
# File size 0.03 MB
# Time taken to download and save data: 1.03 seconds
# Starting job 18/66: Year 2022, Table B25024, Sumlevel 160, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25024_place_state_all_2022.csv
# File size 0.07 MB
# Time taken to download and save data: 0.49 seconds
# Starting job 19/66: Year 2022, Table B25077, Sumlevel 060, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25077_subdivision_state_all_2022.csv
# File size 0.01 MB
# Time taken to download and save data: 0.93 seconds
# Starting job 20/66: Year 2022, Table B25077, Sumlevel 160, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25077_place_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 0.32 seconds
# Starting job 21/66: Year 2022, Table C17002, Sumlevel 060, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\C17002_subdivision_state_all_2022.csv
# File size 0.02 MB
# Time taken to download and save data: 1.28 seconds
# Starting job 22/66: Year 2022, Table C17002, Sumlevel 160, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2022/table-based-SF/data/1YRData/acsdt1y2022-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\C17002_place_state_all_2022.csv
# File size 0.06 MB
# Time taken to download and save data: 0.43 seconds
# Starting job 23/66: Year 2023, Table B01003, Sumlevel 060, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B01003_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.36 seconds
# Starting job 24/66: Year 2023, Table B01003, Sumlevel 160, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B01003_place_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.36 seconds
# Starting job 25/66: Year 2023, Table B07003, Sumlevel 060, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B07003_subdivision_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 1.73 seconds
# Starting job 26/66: Year 2023, Table B07003, Sumlevel 160, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B07003_place_state_all_2023.csv
# File size 0.05 MB
# Time taken to download and save data: 0.47 seconds
# Starting job 27/66: Year 2023, Table B11001, Sumlevel 060, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B11001_subdivision_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.81 seconds
# Starting job 28/66: Year 2023, Table B11001, Sumlevel 160, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B11001_place_state_all_2023.csv
# File size 0.06 MB
# Time taken to download and save data: 0.40 seconds
# Starting job 29/66: Year 2023, Table B19001, Sumlevel 060, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19001_subdivision_state_all_2023.csv
# File size 0.04 MB
# Time taken to download and save data: 0.85 seconds
# Starting job 30/66: Year 2023, Table B19001, Sumlevel 160, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19001_place_state_all_2023.csv
# File size 0.11 MB
# Time taken to download and save data: 0.53 seconds
# Starting job 31/66: Year 2023, Table B19013, Sumlevel 060, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19013_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.81 seconds
# Starting job 32/66: Year 2023, Table B19013, Sumlevel 160, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19013_place_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.37 seconds
# Starting job 33/66: Year 2023, Table B25001, Sumlevel 060, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25001_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.80 seconds
# Starting job 34/66: Year 2023, Table B25001, Sumlevel 160, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25001_place_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.38 seconds
# Starting job 35/66: Year 2023, Table B25002, Sumlevel 060, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25002_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.84 seconds
# Starting job 36/66: Year 2023, Table B25002, Sumlevel 160, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25002_place_state_all_2023.csv
# File size 0.03 MB
# Time taken to download and save data: 0.38 seconds
# Starting job 37/66: Year 2023, Table B25003, Sumlevel 060, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25003_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.87 seconds
# Starting job 38/66: Year 2023, Table B25003, Sumlevel 160, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25003_place_state_all_2023.csv
# File size 0.03 MB
# Time taken to download and save data: 0.60 seconds
# Starting job 39/66: Year 2023, Table B25024, Sumlevel 060, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25024_subdivision_state_all_2023.csv
# File size 0.03 MB
# Time taken to download and save data: 1.94 seconds
# Starting job 40/66: Year 2023, Table B25024, Sumlevel 160, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25024_place_state_all_2023.csv
# File size 0.07 MB
# Time taken to download and save data: 0.81 seconds
# Starting job 41/66: Year 2023, Table B25077, Sumlevel 060, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25077_subdivision_state_all_2023.csv
# File size 0.01 MB
# Time taken to download and save data: 0.76 seconds
# Starting job 42/66: Year 2023, Table B25077, Sumlevel 160, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25077_place_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.30 seconds
# Starting job 43/66: Year 2023, Table C17002, Sumlevel 060, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\C17002_subdivision_state_all_2023.csv
# File size 0.02 MB
# Time taken to download and save data: 0.74 seconds
# Starting job 44/66: Year 2023, Table C17002, Sumlevel 160, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2023/table-based-SF/data/1YRData/acsdt1y2023-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\C17002_place_state_all_2023.csv
# File size 0.06 MB
# Time taken to download and save data: 0.40 seconds
# Starting job 45/66: Year 2024, Table B01003, Sumlevel 060, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B01003_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 0.33 seconds
# Starting job 46/66: Year 2024, Table B01003, Sumlevel 160, State all
#
#  Table: B01003 - Total Population
# Columns: ['B01003_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b01003.dat
# Keeping 3 columns including GEO_ID + B01003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B01003_place_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.37 seconds
# Starting job 47/66: Year 2024, Table B07003, Sumlevel 060, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B07003_subdivision_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.89 seconds
# Starting job 48/66: Year 2024, Table B07003, Sumlevel 160, State all
#
#  Table: B07003 - Geographic Mobility (1 Year)
# Columns: ['B07003_001', 'B07003_004', 'B07003_007', 'B07003_010', 'B07003_013', 'B07003_016']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b07003.dat
# Keeping 13 columns including GEO_ID + B07003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B07003_place_state_all_2024.csv
# File size 0.05 MB
# Time taken to download and save data: 0.42 seconds
# Starting job 49/66: Year 2024, Table B11001, Sumlevel 060, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B11001_subdivision_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 1.08 seconds
# Starting job 50/66: Year 2024, Table B11001, Sumlevel 160, State all
#
#  Table: B11001 - Household Type
# Columns: ['B11001_001', 'B11001_002', 'B11001_003', 'B11001_004', 'B11001_007', 'B11001_008', 'B11001_009']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b11001.dat
# Keeping 15 columns including GEO_ID + B11001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B11001_place_state_all_2024.csv
# File size 0.06 MB
# Time taken to download and save data: 0.38 seconds
# Starting job 51/66: Year 2024, Table B19001, Sumlevel 060, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19001_subdivision_state_all_2024.csv
# File size 0.04 MB
# Time taken to download and save data: 0.86 seconds
# Starting job 52/66: Year 2024, Table B19001, Sumlevel 160, State all
#
#  Table: B19001 - Household Income Distribution
# Columns: ['B19001_001', 'B19001_002', 'B19001_003', 'B19001_004', 'B19001_005', 'B19001_006', 'B19001_007', 'B19001_008', 'B19001_009', 'B19001_010', 'B19001_011', 'B19001_012', 'B19001_013', 'B19001_014', 'B19001_015', 'B19001_016', 'B19001_017']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b19001.dat
# Keeping 35 columns including GEO_ID + B19001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19001_place_state_all_2024.csv
# File size 0.11 MB
# Time taken to download and save data: 0.49 seconds
# Starting job 53/66: Year 2024, Table B19013, Sumlevel 060, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B19013_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 1.13 seconds
# Starting job 54/66: Year 2024, Table B19013, Sumlevel 160, State all
#
#  Table: B19013 - Median Household Income
# Columns: ['B19013_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b19013.dat
# Keeping 3 columns including GEO_ID + B19013 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B19013_place_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.47 seconds
# Starting job 55/66: Year 2024, Table B25001, Sumlevel 060, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25001_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 1.06 seconds
# Starting job 56/66: Year 2024, Table B25001, Sumlevel 160, State all
#
#  Table: B25001 - Housing Units
# Columns: ['B25001_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25001.dat
# Keeping 3 columns including GEO_ID + B25001 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25001_place_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.72 seconds
# Starting job 57/66: Year 2024, Table B25002, Sumlevel 060, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25002_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 1.04 seconds
# Starting job 58/66: Year 2024, Table B25002, Sumlevel 160, State all
#
#  Table: B25002 - Occupancy Status
# Columns: ['B25002_001', 'B25002_002', 'B25002_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25002.dat
# Keeping 7 columns including GEO_ID + B25002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25002_place_state_all_2024.csv
# File size 0.03 MB
# Time taken to download and save data: 0.79 seconds
# Starting job 59/66: Year 2024, Table B25003, Sumlevel 060, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25003_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 0.90 seconds
# Starting job 60/66: Year 2024, Table B25003, Sumlevel 160, State all
#
#  Table: B25003 - Tenure (Owner / Renter)
# Columns: ['B25003_001', 'B25003_002', 'B25003_003']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25003.dat
# Keeping 7 columns including GEO_ID + B25003 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25003_place_state_all_2024.csv
# File size 0.03 MB
# Time taken to download and save data: 0.35 seconds
# Starting job 61/66: Year 2024, Table B25024, Sumlevel 060, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25024_subdivision_state_all_2024.csv
# File size 0.03 MB
# Time taken to download and save data: 1.02 seconds
# Starting job 62/66: Year 2024, Table B25024, Sumlevel 160, State all
#
#  Table: B25024 - Units in Structure
# Columns: ['B25024_001', 'B25024_002', 'B25024_003', 'B25024_004', 'B25024_005', 'B25024_006', 'B25024_007', 'B25024_008', 'B25024_009', 'B25024_010', 'B25024_011']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25024.dat
# Keeping 23 columns including GEO_ID + B25024 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25024_place_state_all_2024.csv
# File size 0.07 MB
# Time taken to download and save data: 0.50 seconds
# Starting job 63/66: Year 2024, Table B25077, Sumlevel 060, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\B25077_subdivision_state_all_2024.csv
# File size 0.01 MB
# Time taken to download and save data: 0.91 seconds
# Starting job 64/66: Year 2024, Table B25077, Sumlevel 160, State all
#
#  Table: B25077 - Median Home Value
# Columns: ['B25077_001']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-b25077.dat
# Keeping 3 columns including GEO_ID + B25077 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\B25077_place_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.36 seconds
# Starting job 65/66: Year 2024, Table C17002, Sumlevel 060, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_county_subdivision\C17002_subdivision_state_all_2024.csv
# File size 0.02 MB
# Time taken to download and save data: 0.81 seconds
# Starting job 66/66: Year 2024, Table C17002, Sumlevel 160, State all
#
#  Table: C17002 - Ratio of Income to Poverty Level
# Columns: ['C17002_001', 'C17002_002', 'C17002_003', 'C17002_004', 'C17002_005', 'C17002_006', 'C17002_007', 'C17002_008']
#
#  Fetching from: https://www2.census.gov/programs-surveys/acs/summary_file/2024/table-based-SF/data/1YRData/acsdt1y2024-c17002.dat
# Keeping 17 columns including GEO_ID + C17002 E/M cols
# Saved: c:\Users\eprashar\OneDrive - CoreLogic Solutions, LLC\github\2026\geo similarity teu\data\raw\ACS\1yr\sumlevel_place\C17002_place_state_all_2024.csv
# File size 0.06 MB
# Time taken to download and save data: 0.39 seconds
